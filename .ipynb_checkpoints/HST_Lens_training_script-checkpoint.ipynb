# %%
#load the real images and their negatives
import os
from astropy.io import fits
import numpy as np
from sklearn.preprocessing import minmax_scale
NEG_PATH = "/home/toyonaga/scratch/augmented_reals_3/dim_negs_norm_aug_noskysubtract/"
#POS_PATH = "/home/roberttoyonaga/notebooks/roberttoyonaga/CMUDeepLensNRC/HSTLens/non-neg-set/merged/"
POS_PATH = "/home/toyonaga/scratch/augmented_reals_3/augmented_reals_separate/"
set_size =1000*2  #includes both pos and neg samples

ims_real = np.ones((set_size, 1, 100, 100))
y_real = np.ones((set_size,1))

#load the negatives into even numbered indices (including 0)
count =0
for filename in os.listdir(NEG_PATH):
    if filename.endswith(".fits") and count<set_size/2: 
        pic = fits.open(NEG_PATH+filename)[0].data
    
#         pic[pic< (3*np.median(pic) - 2*np.average(pic)) +1.5*np.std(pic)] = 0
#         tmp_image = pic.reshape(-1,)
#         tmp_image = np.log10(tmp_image+1)
#         tmp_image = minmax_scale(tmp_image, feature_range = (0,1))
#         pic = tmp_image.reshape(pic.shape[2],pic.shape[2])
        
        ims_real[count*2] = pic
        y_real[count*2] = np.array([0])
        count+=1
    
    
#load the positives into odd numered indices
count =0
for filename in os.listdir(POS_PATH):
    if filename.endswith(".fits") and count<set_size/2: 
        pic = fits.open(POS_PATH+filename)[0].data
        
#         pic[pic< (3*np.median(pic) - 2*np.average(pic)) +1.5*np.std(pic)] = 0
#         tmp_image = pic.reshape(-1,)
#         tmp_image = np.log10(tmp_image+1)
#         tmp_image = minmax_scale(tmp_image, feature_range = (0,1))
#         pic = tmp_image.reshape(pic.shape[2],pic.shape[2])
        
        ims_real[count*2+1] = pic
        y_real[count*2+1] = np.array([1])
        count+=1

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %aimport -numpy
# %aimport -os
# %aimport -minmax_scale
# %aimport -tensorflow
#%aimport -keras
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib
# /project/6016730/mlhaa/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['shuffle']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from HSTLens_resnet10_CC import deeplens_classifier
from HSTLens_base_classifier_resnet10_CC import BaseKerasClassifier
from HSTLens_blocks_resnet10_CC import pre_activated_resnet_block

# %%
import os
from astropy.io import fits
import numpy as np
from sklearn.preprocessing import minmax_scale

NEG_PATH = "/home/toyonaga/scratch/skysubtracted5600/neg/" 
#POS_PATH = "/home/roberttoyonaga/notebooks/roberttoyonaga/CMUDeepLensNRC/HSTLens/non-neg-set/merged/"
POS_PATH = "/home/toyonaga/scratch/skysubtracted5600/pos/"
set_size =5600*2  #includes both pos and neg samples

ims = np.ones((set_size, 1, 100, 100))
y = np.ones((set_size,1))

#load the negatives into even numbered indices (including 0)
count =0
for filename in os.listdir(NEG_PATH):
    if filename.endswith(".fits") and count<set_size/2: 
        pic = fits.open(NEG_PATH+filename)[0].data
        
#         pic[pic< (3*np.median(pic) - 2*np.average(pic)) +1.5*np.std(pic)] = 0
#         tmp_image = pic.reshape(-1,)
#         tmp_image = np.log10(tmp_image+1)
#         tmp_image = minmax_scale(tmp_image, feature_range = (0,1))
#         pic = tmp_image.reshape(pic.shape[0],pic.shape[1])
        
        ims[count*2] = pic
        y[count*2] = np.array([0])
        count+=1
    
    
#load the positives into odd numered indices
count =0
for filename in os.listdir(POS_PATH):
    if filename.endswith(".fits") and count<set_size/2: 
        pic = fits.open(POS_PATH+filename)[0].data
        
#         pic[pic< (3*np.median(pic) - 2*np.average(pic)) +1.5*np.std(pic)] = 0
#         tmp_image = pic.reshape(-1,)
#         tmp_image = np.log10(tmp_image+1)
#         tmp_image = minmax_scale(tmp_image, feature_range = (0,1))
#         pic = tmp_image.reshape(pic.shape[0],pic.shape[1])
        
        ims[count*2+1] = pic
        y[count*2+1] = np.array([1])
        count+=1

# %%
import matplotlib.pyplot as plt

i =9736




print(y_combined_shuf[i])
plt.imshow(x_combined_shuf[i][0])
#ims[i][0].mean(), ims[i+1][0].mean()
# Out:
# [1.]

# %%
import matplotlib.pyplot as plt
import random
#first shuffle the large set of simulated data and the real data because we are not using all of it
s1 = np.arange(ims.shape[0])
np.random.shuffle(s1)
ims_shuf = ims[s1]
y_shuf = y[s1]


#combine part of the shuffled simulated and real data
x_combined = np.concatenate((ims_shuf[:10000], ims_real)) #leave out 500 real+neg for the testing
y_combined = np.concatenate((y_shuf[:10000], y_real))

#shuffle the combined array
s3 = np.arange(x_combined.shape[0])
np.random.shuffle(s3)

x_combined_shuf =x_combined[s3]
y_combined_shuf = y_combined[s3]

# %%
import tensorflow
import keras
from keras.layers import Activation
from keras.layers import Conv2D, ELU
from HSTLens_resnet13_CC import deeplens_classifier
# from HSTLens_base_classifier_resnet6_CC_l2 import BaseKerasClassifier
# from HSTLens_blocks_resnet15_CC import pre_activated_resnet_block
from keras.layers.normalization import BatchNormalization
my_model = deeplens_classifier(n_epochs=20)
my_model._build(x_combined_shuf,y_combined_shuf) 

my_model._fit(x_combined_shuf,y_combined_shuf)

#my_model.model.save("real_lenses_weights") # issue with json serializing
my_model.model.save_weights("combined_nonsubtracted_weights_resnet15_CC_2")
#my_model.model.load_weights("test real lens weights")
# Out:
# building resnet15_2
# RESNET15_CC
# pre- resnet block entered!
# RESNET15_C BLOCKS_2
# shorcut (?, 32, 100, 100) net (?, 32, 100, 100)
# pre- resnet block entered!
# RESNET15_C BLOCKS_2
# shorcut (?, 32, 100, 100) net (?, 32, 100, 100)
# pre- resnet block entered!
# RESNET15_C BLOCKS_2
# shorcut (?, 32, 100, 100) net (?, 32, 100, 100)
# pre- resnet block entered!
# RESNET15_C BLOCKS_2
# shorcut (?, 64, 100, 100) net (?, 64, 100, 100)
# pre- resnet block entered!
# RESNET15_C BLOCKS_2
# shorcut (?, 64, 100, 100) net (?, 64, 100, 100)
# pre- resnet block entered!
# RESNET15_C BLOCKS_2
# shorcut (?, 64, 100, 100) net (?, 64, 100, 100)
# pre- resnet block entered!
# RESNET15_C BLOCKS_2
# shorcut (?, 128, 100, 100) net (?, 128, 100, 100)
# pre- resnet block entered!
# RESNET15_C BLOCKS_2
# shorcut (?, 128, 100, 100) net (?, 128, 100, 100)
# pre- resnet block entered!
# RESNET15_C BLOCKS_2
# shorcut (?, 128, 100, 100) net (?, 128, 100, 100)
# ...Fitting model ...
# Train on 9600 samples, validate on 2400 samples
# Epoch 1/20
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#
# ResourceExhaustedError: OOM when allocating tensor with shape[320000,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: training_19/Adam/Variable_146/Assign = Assign[T=DT_FLOAT, use_locking=true, validate_shape=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](training_19/Adam/Variable_146, training_19/Adam/zeros_146)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-88-28c85ec2b1a3> in <module>()
#      10 my_model._build(x_combined_shuf,y_combined_shuf)
#      11
# ---> 12 my_model._fit(x_combined_shuf,y_combined_shuf)
#      13
#      14 #my_model.model.save("real_lenses_weights") # issue with json serializing
#
# /project/6016730/toyonaga/HSTLens/HSTLens_base_classifier_resnet15_CC.py in _fit(self, data, labels)
#     127
#     128         self.model.fit(data, labels, batch_size=self.batch_size, callbacks=callbacks_list,
# --> 129                        shuffle= True, validation_split = 0.2, epochs= self.n_epochs)
#     130
#     131         self.fitted=True
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     144         for m in model.stateful_metric_functions:
#     145             m.reset_states()
# --> 146         callbacks.on_epoch_begin(epoch)
#     147         epoch_logs = {}
#     148         if steps_per_epoch is not None:
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/keras/callbacks.py in on_epoch_begin(self, epoch, logs)
#      61         logs = logs or {}
#      62         for callback in self.callbacks:
# ---> 63             callback.on_epoch_begin(epoch, logs)
#      64         self._delta_t_batch = 0.
#      65         self._delta_ts_batch_begin = deque([], maxlen=self.queue_length)
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/keras/callbacks.py in on_epoch_begin(self, epoch, logs)
#     625         if not hasattr(self.model.optimizer, 'lr'):
#     626             raise ValueError('Optimizer must have a "lr" attribute.')
# --> 627         lr = float(K.get_value(self.model.optimizer.lr))
#     628         try:  # new API
#     629             lr = self.schedule(epoch, lr)
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in get_value(x)
#    2375         A Numpy array.
#    2376     """
# -> 2377     return x.eval(session=get_session())
#    2378
#    2379
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in get_session()
#     202                     v._keras_initialized = True
#     203                 if uninitialized_vars:
# --> 204                     session.run(tf.variables_initializer(uninitialized_vars))
#     205     # hack for list_devices() function.
#     206     # list_devices() function is not available under tensorflow r1.3.
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1333         except KeyError:
#    1334           pass
# -> 1335       raise type(e)(node_def, op, message)
#    1336
#    1337   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[320000,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: training_19/Adam/Variable_146/Assign = Assign[T=DT_FLOAT, use_locking=true, validate_shape=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](training_19/Adam/Variable_146, training_19/Adam/zeros_146)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Caused by op 'training_19/Adam/Variable_146/Assign', defined at:
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.6.3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.6.3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 497, in start
#     self.io_loop.start()
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.6.3/lib/python3.6/asyncio/base_events.py", line 421, in run_forever
#     self._run_once()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.6.3/lib/python3.6/asyncio/base_events.py", line 1426, in _run_once
#     handle._run()
#   File "/cvmfs/soft.computecanada.ca/easybuild/software/2017/Core/python/3.6.3/lib/python3.6/asyncio/events.py", line 127, in _run
#     self._callback(*self._args)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2901, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-88-28c85ec2b1a3>", line 12, in <module>
#     my_model._fit(x_combined_shuf,y_combined_shuf)
#   File "/project/6016730/toyonaga/HSTLens/HSTLens_base_classifier_resnet15_CC.py", line 129, in _fit
#     shuffle= True, validation_split = 0.2, epochs= self.n_epochs)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/keras/engine/training.py", line 1008, in fit
#     self._make_train_function()
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/keras/engine/training.py", line 498, in _make_train_function
#     loss=self.total_loss)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/keras/optimizers.py", line 482, in get_updates
#     ms = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/keras/optimizers.py", line 482, in <listcomp>
#     ms = [K.zeros(K.int_shape(p), dtype=K.dtype(p)) for p in params]
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 702, in zeros
#     return variable(v, dtype=dtype, name=name)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 400, in variable
#     v = tf.Variable(value, dtype=tf.as_dtype(dtype), name=name)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/ops/variables.py", line 235, in __init__
#     constraint=constraint)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/ops/variables.py", line 387, in _init_from_args
#     validate_shape=validate_shape).op
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/ops/state_ops.py", line 283, in assign
#     validate_shape=validate_shape)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/ops/gen_state_ops.py", line 60, in assign
#     use_locking=use_locking, name=name)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3392, in create_op
#     op_def=op_def)
#   File "/project/6016730/mlhaa/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1718, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[320000,512] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: training_19/Adam/Variable_146/Assign = Assign[T=DT_FLOAT, use_locking=true, validate_shape=true, _device="/job:localhost/replica:0/task:0/device:GPU:0"](training_19/Adam/Variable_146, training_19/Adam/zeros_146)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %%
(my_model.batch_history.epoch_losses)
# Out:
# [0.745, 0.76, 0.75, 0.82, 0.86, 0.855, 0.825, 0.875, 0.875, 0.9]

# %%
import matplotlib.pyplot as plt
import sklearn.metrics as metrics
x_combined_roc = np.concatenate((ims_shuf[10000:], ims_real_test))
y_combined_roc = np.concatenate((y_shuf[10000:], y_real_test))
fpr, tpr, t=my_model.eval_ROC(x_combined_roc,y_combined_roc)
print("auc "+str( metrics.auc(fpr, tpr)))

plt.title('non  sky subtracted -separated reals_resnet15_CC_2')
plt.plot(fpr,tpr)
plt.xlabel('FPR'); 
plt.ylabel('TPR')
plt.xlim(0,0.4); 
plt.ylim(0,1)
plt.grid('on')
# Out:
# auc 0.9726974122982526
# /project/6016730/mlhaa/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
#my_model.model.history is a callback obj my_model.model.history is a dict
train_loss = my_model.model.history.history['loss'] 
val_loss = my_model.model.history.history['val_loss']
xc = range(20)

plt.figure()
plt.title('non-skysubtracted loss curves -separated reals_resnet6_CC_2_l2_003')
plt.xlabel('epochs');
plt.ylabel('loss')
plt.plot(xc, train_loss,'r-',label="train loss")
plt.plot(xc, val_loss, 'b-',label="validation loss")
plt.grid('on')
plt.legend()
# Out:
# /project/6016730/mlhaa/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
start = time.time()
predictions= my_model._predict(x[:1000],y[:1000])
duration = time.time()-start
print(duration)

''' 
12.427s for 100 predictions
1.28s for 10 predicitons
97.0560390949 for 1000 predictions 
'''
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-671-9544e4702b51> in <module>()
#       1 start = time.time()
# ----> 2 predictions= my_model._predict(x[:1000],y[:1000])
#       3 duration = time.time()-start
#       4 print(duration)
#       5
#
# NameError: name 'x' is not defined

# %%
acc = my_model.model.history.history['acc'] 
val_acc = my_model.model.history.history['val_acc'] 
xc =range(20)
plt.figure()
plt.title('non-skysubtraction -separated reals_resnet6_CC_2_l2_003')
plt.xlabel('epochs')
plt.ylabel('acc')
plt.plot(xc, acc,'r-',label="acc")
plt.plot(xc, val_acc,'b-',label=" valid acc")
plt.grid('on')
plt.legend()
# Out:
# /project/6016730/mlhaa/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
x_test = np.load('pos_real_nonskysubtracted_x1.npy')
y_test = np.load('pos_real_nonskysubtracted_y1.npy')
x_test.shape
# Out:
# (420, 1, 100, 100)

# %%
i = 1183

print( ims_real_test.shape)
plt.imshow(ims_real_test[i][0])
print(y_real_test[i])
# Out:
# (1200, 1, 100, 100)
# [1.]

# %%
#load the real TEST images and their negatives
import os
from astropy.io import fits
import numpy as np
#from sklearn.preprocessing import minmax_scale
from random import shuffle
NEG_PATH = "/home/toyonaga/scratch/augmented_reals_3/dim_negs_norm_aug_noskysubtract/"
#POS_PATH = "/home/roberttoyonaga/notebooks/roberttoyonaga/CMUDeepLensNRC/HSTLens/non-neg-set/merged/"
POS_PATH = "/home/toyonaga/scratch/augmented_reals_3/augmented_reals_separate_test/"
set_size =15*40*2  #includes both pos and neg samples

ims_real_test = np.ones((set_size, 1, 100, 100))
y_real_test = np.ones((set_size,1))

#load the negatives into even numbered indices (including 0)
count =0
neg_list = os.listdir(NEG_PATH)
shuffle(neg_list)
for filename in neg_list:
    if filename.endswith(".fits") and count<set_size/2: 
        pic = fits.open(NEG_PATH+filename)[0].data
    
#         pic[pic< (3*np.median(pic) - 2*np.average(pic)) +1.5*np.std(pic)] = 0
#         tmp_image = pic.reshape(-1,)
#         tmp_image = np.log10(tmp_image+1)
#         tmp_image = minmax_scale(tmp_image, feature_range = (0,1))
#         pic = tmp_image.reshape(pic.shape[2],pic.shape[2])
        
        ims_real_test[count*2] = pic
        y_real_test[count*2] = np.array([0])
        count+=1
    
    
#load the positives into odd numered indices
count =0
pos_list = os.listdir(POS_PATH)
shuffle(pos_list)
for filename in pos_list:
    if filename.endswith(".fits") and count<set_size/2: 
        pic = fits.open(POS_PATH+filename)[0].data
        
#         pic[pic< (3*np.median(pic) - 2*np.average(pic)) +1.5*np.std(pic)] = 0
#         tmp_image = pic.reshape(-1,)
#         tmp_image = np.log10(tmp_image+1)
#         tmp_image = minmax_scale(tmp_image, feature_range = (0,1))
#         pic = tmp_image.reshape(pic.shape[2],pic.shape[2])
        
        ims_real_test[count*2+1] = pic
        y_real_test[count*2+1] = np.array([1])
        count+=1

# %%
predictions  = my_model._predict( ims_real_test, y= None, discrete = True)
tp =0.
fp =0.
fn=0.
pos =0.
for i in range(len(predictions)):
    if (predictions[i] ==1) and( y_real_test[i] ==1):
        tp+=1
        pos+=1
        
    if (predictions[i] == 1) and (y_real_test[i]==0): 
        fp+=1
        #print ("fp"+ str(i))
    if (predictions[i] == 0 ) and (y_real_test[i] ==1):
        fn+=1
        pos+=1
        #print( "fn"+ str(i))
        
print ("fpr: ", fp/pos,"tpr: ", tp/pos ,"fp ",fp, "tp ",  tp,"fn ", fn)
# Out:
# ...Generating Predictions ...
# fpr:  0.015 tpr:  0.8316666666666667 fp  9.0 tp  499.0 fn  101.0

# %%
#pur, comp = my_model.eval_purity_completeness(ims_shuf[10000:], y_shuf[10000:])
pur, comp = my_model.eval_purity_completeness(ims_real_test,y_real_test)
"purity" + str(pur),"comp" + str(comp)
# Out:
# ...Generating Predictions ...
# ('purity0.963855421686747', 'comp0.9333333333333333')
